# %% [markdown]
# <a href="https://colab.research.google.com/github/kakecat/-/blob/main/exam_editor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # sample exercises
#
# 1. 課題の取り組み方について学習します。

# %% [markdown]
# ### 1. 課題の取り組み方について学習します。

# %% [markdown]
# #### 1.1 「変数num1を定義して、num1に8を代入して、表示してください。」

# %%
num1 = 8
print(num1)
# Out:
# 8

# %% [markdown]
# #### 1.2 「変数num2を定義して、num2に4を代入して、表示してください。」

# %%
num2 = 4
print(num2)
# Out:
# 4

# %% [markdown]
# #### 1.3 「変数num1とnum2の和を求めてください。」

# %%
num1 + num2
# Out:
# 12

# %% [markdown]
# #### 1.4 「変数num1とnum2の差を求めてください。」

# %%
num1 - num2
# Out:
# 4

# %% [markdown]
# #### 1.5 「変数num1とnum2の積を求めてください。」

# %%
num1 * num2
# Out:
# 32

# %% [markdown]
# #### 1.6 「変数num1とnum2の商を求めてください。」

# %%
num1 / num2
# Out:
# 2.0
